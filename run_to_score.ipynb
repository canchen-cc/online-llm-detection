# %%
/home/jupyter

# %%
import torch

print(torch.cuda.is_available())  # 应该输出 True 如果CUDA可用
print(torch.__version__)  # 输出安装的PyTorch版本
print(torch.version.cuda)  # 输出PyTorch使用的CUDA版本

# %%
#roberta-base
import time
start=time.time()
# !python /home/jupyter/scripts/supervised.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --model_name 'roberta-base-openai-detector' --device 'cuda' --cache_dir '/home/jupyter/gcs-mount/cache'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Python EXE: /opt/conda/bin/python
# Beginning supervised evaluation with roberta-base-openai-detector...
# config.json: 100%|█████████████████████████████| 624/624 [00:00<00:00, 6.09MB/s]
# model.safetensors: 100%|██████████████████████| 501M/501M [00:03<00:00, 137MB/s]
# Some weights of the model checkpoint at roberta-base-openai-detector were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
#roberta-large
import time
start=time.time()
# !python /home/jupyter/scripts/supervised.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --model_name 'roberta-large-openai-detector' --device 'cuda' --cache_dir '/home/jupyter/gcs-mount/cache'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Python EXE: /opt/conda/bin/python
# Beginning supervised evaluation with roberta-large-openai-detector...
# config.json: 100%|█████████████████████████████| 519/519 [00:00<00:00, 4.89MB/s]
# model.safetensors: 100%|████████████████████| 1.43G/1.43G [00:08<00:00, 173MB/s]
# Some weights of the model checkpoint at roberta-large-openai-detector were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
#detect-gpt
import time
import os
start=time.time()
# !python /home/jupyter/scripts/detect_gpt.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --n_perturbations 100 --scoring_model_name 'gemma-2b' --device 'cuda'\
        --cache_dir '/home/jupyter/gcs-mount/cache' --hf_token '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'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Loading mask filling model google-t5/t5-3b...
# config.json: 100%|█████████████████████████| 1.20k/1.20k [00:00<00:00, 7.49MB/s]
# model.safetensors: 100%|████████████████████| 11.4G/11.4G [00:51<00:00, 222MB/s]
# spiece.model: 100%|██████████████████████████| 792k/792k [00:00<00:00, 15.6MB/s]
# tokenizer.json: 100%|██████████████████████| 1.39M/1.39M [00:00<00:00, 28.5MB/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Raw data loaded from /home/jupyter/data/xsum.gemini_1.5_flash.raw_data.json
# Perturb text:  42%|█████████▋             | 211/500 [1:40:21<2:17:26, 28.54s/it]
# Traceback (most recent call last):
# ...

# %%
#detect-llm
import time
import os
start=time.time()
# !python /home/jupyter/scripts/detect_llm.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --n_perturbations 100 --scoring_model_name 'gemma-2b' --device 'cuda'\
        --cache_dir '/home/jupyter/gcs-mount/cache' --hf_token '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'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Traceback (most recent call last):
#   File "/home/jupyter/scripts/detect_llm.py", line 142, in <module>
#     experiment(args)
#   File "/home/jupyter/scripts/detect_llm.py", line 78, in experiment
#     generate_perturbs(args)
# NameError: name 'generate_perturbs' is not defined
# run0.053994659582773843mins

# %%
#fastdetect-gpt
import time
start=time.time()
# !python /home/jupyter/scripts/fast_detect_gpt.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --reference_model_name 'gpt-j-6B' \
        --scoring_model_name 'gemma-2b' --device 'cuda' --cache_dir '/home/jupyter/gcs-mount/cache'\
        --hf_token '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'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# tokenizer_config.json: 100%|████████████████| 33.6k/33.6k [00:00<00:00, 140MB/s]
# tokenizer.model: 100%|█████████████████████| 4.24M/4.24M [00:00<00:00, 54.1MB/s]
# tokenizer.json: 100%|███████████████████████| 17.5M/17.5M [00:00<00:00, 224MB/s]
# special_tokens_map.json: 100%|█████████████████| 636/636 [00:00<00:00, 7.19MB/s]
# Loading model google/gemma-2b...
# config.json: 100%|█████████████████████████████| 627/627 [00:00<00:00, 7.47MB/s]
# model.safetensors.index.json: 100%|█████████| 13.5k/13.5k [00:00<00:00, 105MB/s]
# ...
# model-00001-of-00002.safetensors:   0%|             | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1%|     | 31.5M/4.95G [00:00<00:20, 242MB/s]
# model-00001-of-00002.safetensors:   1%|     | 62.9M/4.95G [00:00<00:21, 228MB/s]
# model-00001-of-00002.safetensors:   2%|     | 94.4M/4.95G [00:00<00:21, 227MB/s]
# model-00001-of-00002.safetensors:   3%|▏     | 126M/4.95G [00:00<00:21, 225MB/s]
# ...

# %%
#dna-gpt
import time
start=time.time()
# !python /home/jupyter/scripts/dna_gpt.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --base_model_name 'gemma-2b' --device 'cuda'\
        --cache_dir '/home/jupyter/gcs-mount/cache' --hf_token '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'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Loading model google/gemma-2b...
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:08<00:00,  4.16s/it]
# Moving model to GPU...DONE (1.37s)
# Raw data loaded from /home/jupyter/data/xsum.gemini_1.5_flash.raw_data.json
# Computing dna_gpt criterion:   0%|                      | 0/500 [00:00<?, ?it/s]Generating samples for batch 0 of 1
# Generating samples for batch 0 of 1
# Computing dna_gpt criterion:   0%|            | 1/500 [00:07<1:05:39,  7.89s/it]Generating samples for batch 0 of 1
# Generating samples for batch 0 of 1
# Computing dna_gpt criterion:   0%|              | 2/500 [00:14<58:46,  7.08s/it]Generating samples for batch 0 of 1
# ...

# %%
#baselines
import time
start=time.time()
# !python /home/jupyter/scripts/baselines.py --output_file '/home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b'\
        --dataset_file '/home/jupyter/data/xsum.gemini_1.5_flash' --scoring_model_name 'gemma-2b' --device 'cuda'\
        --cache_dir '/home/jupyter/gcs-mount/cache' --hf_token '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'
end=time.time()
print(f"run{(end-start)/60}mins")
# Out:
# Loading model google/gemma-2b...
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:01<00:00,  1.37it/s]
# Moving model to GPU...DONE (1.35s)
# Raw data loaded from /home/jupyter/data/xsum.gemini_1.5_flash.raw_data.json
# Computing likelihood criterion: 100%|█████████| 500/500 [00:27<00:00, 18.02it/s]
# Criterion likelihood_threshold ROC AUC: 0.8489, PR AUC: 0.8493
# Results written into /home/jupyter/results/xsum.gemini_1.5_flash.gemma_2b.likelihood.json
# Computing rank criterion: 100%|███████████████| 500/500 [00:38<00:00, 12.94it/s]
# Criterion rank_threshold ROC AUC: 0.5606, PR AUC: 0.6307
# ...
